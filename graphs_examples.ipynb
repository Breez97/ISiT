# %% [markdown]
# <b>Сбор данных о друзьях из VK в таблицу</b>

# %%
# %pip install jinja2
# %pip install matplotlib
# %pip install networkx
# %pip install openpyxl
# %pip install pandas
# %pip install requests
# %pip install seaborn
# %pip install scipy
# Out:
# Requirement already satisfied: requests in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from requests) (2025.10.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\breez\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\breez\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openpyxl in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from openpyxl) (2.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: networkx in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (3.5)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\breez\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\breez\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\breez\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (1.16.2)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from scipy) (2.3.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: jinja2 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\breez\appdata\local\programs\python\python313\lib\site-packages (from jinja2) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
import pandas as pd
import requests
from collections import deque
from IPython.display import display

# %%
BASE_URL = "https://api.vk.ru/method/"
ACCESS_TOKEN = ""
API_VERSION = "5.199"

START_USER = 293108529
MAX_EDGES = 12000
MAX_FRIENDS_PER_USER = 100


def vk_request(method, params):
    params["access_token"] = ACCESS_TOKEN
    params["v"] = API_VERSION
    try:
        resp = requests.get(BASE_URL + method, params=params, timeout=10)
        data = resp.json()
        if "response" in data:
            return data["response"]
        else:
            print("VK error:", data)
            return None
    except Exception as e:
        print("Request error:", e)
        return None


def get_user_info(user_ids):
    if not user_ids:
        return {}
    ids_str = ",".join(map(str, user_ids))
    response = vk_request("users.get", {"user_ids": ids_str})
    users = {}
    if response:
        for u in response:
            users[u["id"]] = f"{u['first_name']} {u['last_name']}"
    return users


def get_friends(user_id):
    response = vk_request("friends.get", {"user_id": user_id})
    if response:
        return response["items"][:MAX_FRIENDS_PER_USER]
    return []

edges = []
visited = set()
to_visit = [START_USER]

while to_visit and len(edges) < MAX_EDGES:
    user_id = to_visit.pop(0)
    if user_id in visited:
        continue
    visited.add(user_id)

    friends = get_friends(user_id)
    user_info = get_user_info([user_id])
    friends_info = get_user_info(friends)

    for f in friends:
        if len(edges) >= MAX_EDGES:
            break
        name1 = user_info.get(user_id, "Unknown")
        name2 = friends_info.get(f, "Unknown")
        edges.append((user_id, name1, f, name2))
        to_visit.append(f)

    print(f"{user_id}: added {len(friends)} friends (total amount of relations {len(edges)})")

print(f"\nCollecting finished: {len(edges)} relations")

df = pd.DataFrame(edges, columns=["user_id_1", "name_1", "user_id_2", "name_2"])
df.insert(0, "id", range(1, len(df) + 1))
df.to_excel("vk_friends_limited.xlsx", index=False)
# Out:
# 293108529: added 97 friends (total amount of relations 97)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1093805'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1093805: added 0 friends (total amount of relations 97)
# 5372286: added 100 friends (total amount of relations 197)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '14659428'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 14659428: added 0 friends (total amount of relations 197)
# 45210966: added 88 friends (total amount of relations 285)
# 51256587: added 100 friends (total amount of relations 385)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '52300155'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 52300155: added 0 friends (total amount of relations 385)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '58535499'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 58535499: added 0 friends (total amount of relations 385)
# 71913479: added 20 friends (total amount of relations 405)
# 108376754: added 100 friends (total amount of relations 505)
# 122462960: added 100 friends (total amount of relations 605)
# 136019848: added 100 friends (total amount of relations 705)
# 147967801: added 100 friends (total amount of relations 805)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '157518430'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 157518430: added 0 friends (total amount of relations 805)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '158342502'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 158342502: added 0 friends (total amount of relations 805)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '164911154'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 164911154: added 0 friends (total amount of relations 805)
# 166523784: added 92 friends (total amount of relations 897)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '168258820'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 168258820: added 0 friends (total amount of relations 897)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '177635297'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 177635297: added 0 friends (total amount of relations 897)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '189961159'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 189961159: added 0 friends (total amount of relations 897)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '191315110'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 191315110: added 0 friends (total amount of relations 897)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '191596723'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 191596723: added 0 friends (total amount of relations 897)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '192499563'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 192499563: added 0 friends (total amount of relations 897)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '194440244'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 194440244: added 0 friends (total amount of relations 897)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '196002699'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 196002699: added 0 friends (total amount of relations 897)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '201508684'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 201508684: added 0 friends (total amount of relations 897)
# 202441545: added 100 friends (total amount of relations 997)
# 207333440: added 38 friends (total amount of relations 1035)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '212094806'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 212094806: added 0 friends (total amount of relations 1035)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '212173736'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 212173736: added 0 friends (total amount of relations 1035)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '215592225'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 215592225: added 0 friends (total amount of relations 1035)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '224745131'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 224745131: added 0 friends (total amount of relations 1035)
# 225030004: added 100 friends (total amount of relations 1135)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '225954408'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 225954408: added 0 friends (total amount of relations 1135)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '241206366'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 241206366: added 0 friends (total amount of relations 1135)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '246760178'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 246760178: added 0 friends (total amount of relations 1135)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '247033023'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 247033023: added 0 friends (total amount of relations 1135)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '247876323'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 247876323: added 0 friends (total amount of relations 1135)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '248155379'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 248155379: added 0 friends (total amount of relations 1135)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '262133611'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 262133611: added 0 friends (total amount of relations 1135)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '264003175'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 264003175: added 0 friends (total amount of relations 1135)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '265282688'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 265282688: added 0 friends (total amount of relations 1135)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '266099466'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 266099466: added 0 friends (total amount of relations 1135)
# 266842767: added 100 friends (total amount of relations 1235)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '277112169'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 277112169: added 0 friends (total amount of relations 1235)
# 277525590: added 100 friends (total amount of relations 1335)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '279330285'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 279330285: added 0 friends (total amount of relations 1335)
# 279466494: added 20 friends (total amount of relations 1355)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '282247866'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 282247866: added 0 friends (total amount of relations 1355)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '282619911'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 282619911: added 0 friends (total amount of relations 1355)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '293430054'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 293430054: added 0 friends (total amount of relations 1355)
# 296519014: added 100 friends (total amount of relations 1455)
# 297780677: added 66 friends (total amount of relations 1521)
# 298442650: added 100 friends (total amount of relations 1621)
# 308706433: added 100 friends (total amount of relations 1721)
# 310065949: added 100 friends (total amount of relations 1821)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '312638649'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 312638649: added 0 friends (total amount of relations 1821)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '312883585'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 312883585: added 0 friends (total amount of relations 1821)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '313372281'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 313372281: added 0 friends (total amount of relations 1821)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '317003238'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 317003238: added 0 friends (total amount of relations 1821)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '324039734'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 324039734: added 0 friends (total amount of relations 1821)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '324460152'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 324460152: added 0 friends (total amount of relations 1821)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '333161209'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 333161209: added 0 friends (total amount of relations 1821)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '335973985'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 335973985: added 0 friends (total amount of relations 1821)
# 339786436: added 100 friends (total amount of relations 1921)
# 350578221: added 100 friends (total amount of relations 2021)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '351317340'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 351317340: added 0 friends (total amount of relations 2021)
# 351516885: added 98 friends (total amount of relations 2119)
# 353467378: added 100 friends (total amount of relations 2219)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '353514981'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 353514981: added 0 friends (total amount of relations 2219)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '382181094'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 382181094: added 0 friends (total amount of relations 2219)
# 390851041: added 93 friends (total amount of relations 2312)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '393329952'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 393329952: added 0 friends (total amount of relations 2312)
# 399743744: added 100 friends (total amount of relations 2412)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '419697671'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 419697671: added 0 friends (total amount of relations 2412)
# 454785920: added 100 friends (total amount of relations 2512)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '463297336'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 463297336: added 0 friends (total amount of relations 2512)
# 467165172: added 100 friends (total amount of relations 2612)
# 467788958: added 100 friends (total amount of relations 2712)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '469371932'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 469371932: added 0 friends (total amount of relations 2712)
# 471890474: added 100 friends (total amount of relations 2812)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '483025012'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 483025012: added 0 friends (total amount of relations 2812)
# 491881473: added 66 friends (total amount of relations 2878)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '502941974'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 502941974: added 0 friends (total amount of relations 2878)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '507163481'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 507163481: added 0 friends (total amount of relations 2878)
# 509292664: added 65 friends (total amount of relations 2943)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '517283357'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 517283357: added 0 friends (total amount of relations 2943)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '517544543'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 517544543: added 0 friends (total amount of relations 2943)
# 547919988: added 100 friends (total amount of relations 3043)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '550801509'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 550801509: added 0 friends (total amount of relations 3043)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '568911655'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 568911655: added 0 friends (total amount of relations 3043)
# 572835602: added 100 friends (total amount of relations 3143)
# 575370485: added 54 friends (total amount of relations 3197)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '599138693'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 599138693: added 0 friends (total amount of relations 3197)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '613944257'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 613944257: added 0 friends (total amount of relations 3197)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '692516441'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 692516441: added 0 friends (total amount of relations 3197)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '694382939'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 694382939: added 0 friends (total amount of relations 3197)
# 812428724: added 8 friends (total amount of relations 3205)
# 1765: added 100 friends (total amount of relations 3305)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '30586'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 30586: added 0 friends (total amount of relations 3305)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '159497'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 159497: added 0 friends (total amount of relations 3305)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '162952'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 162952: added 0 friends (total amount of relations 3305)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '168013'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 168013: added 0 friends (total amount of relations 3305)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '169999'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 169999: added 0 friends (total amount of relations 3305)
# 179062: added 100 friends (total amount of relations 3405)
# 227014: added 100 friends (total amount of relations 3505)
# 227795: added 100 friends (total amount of relations 3605)
# 236394: added 100 friends (total amount of relations 3705)
# 248984: added 100 friends (total amount of relations 3805)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '316855'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 316855: added 0 friends (total amount of relations 3805)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '391149'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 391149: added 0 friends (total amount of relations 3805)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '545634'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 545634: added 0 friends (total amount of relations 3805)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '561440'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 561440: added 0 friends (total amount of relations 3805)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '585620'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 585620: added 0 friends (total amount of relations 3805)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '612499'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 612499: added 0 friends (total amount of relations 3805)
# 640037: added 100 friends (total amount of relations 3905)
# 991562: added 100 friends (total amount of relations 4005)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1080516'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1080516: added 0 friends (total amount of relations 4005)
# 1134070: added 100 friends (total amount of relations 4105)
# 1170932: added 100 friends (total amount of relations 4205)
# 1206890: added 100 friends (total amount of relations 4305)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1237703'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1237703: added 0 friends (total amount of relations 4305)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1325314'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1325314: added 0 friends (total amount of relations 4305)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1371471'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1371471: added 0 friends (total amount of relations 4305)
# 1407995: added 37 friends (total amount of relations 4342)
# 1436295: added 100 friends (total amount of relations 4442)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1439755'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1439755: added 0 friends (total amount of relations 4442)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1448855'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1448855: added 0 friends (total amount of relations 4442)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1487137'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1487137: added 0 friends (total amount of relations 4442)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1546039'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1546039: added 0 friends (total amount of relations 4442)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1547006'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1547006: added 0 friends (total amount of relations 4442)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1573526'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1573526: added 0 friends (total amount of relations 4442)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1593268'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1593268: added 0 friends (total amount of relations 4442)
# 1593872: added 100 friends (total amount of relations 4542)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1619403'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1619403: added 0 friends (total amount of relations 4542)
# 1643890: added 100 friends (total amount of relations 4642)
# 1669436: added 100 friends (total amount of relations 4742)
# 1709845: added 100 friends (total amount of relations 4842)
# 1731627: added 100 friends (total amount of relations 4942)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1793332'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1793332: added 0 friends (total amount of relations 4942)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1807275'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1807275: added 0 friends (total amount of relations 4942)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1868394'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1868394: added 0 friends (total amount of relations 4942)
# 1921119: added 100 friends (total amount of relations 5042)
# 1926710: added 100 friends (total amount of relations 5142)
# 2009455: added 100 friends (total amount of relations 5242)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2012980'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2012980: added 0 friends (total amount of relations 5242)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2087901'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2087901: added 0 friends (total amount of relations 5242)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2089661'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2089661: added 0 friends (total amount of relations 5242)
# 2197436: added 100 friends (total amount of relations 5342)
# 2223752: added 100 friends (total amount of relations 5442)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2282997'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2282997: added 0 friends (total amount of relations 5442)
# 2286558: added 100 friends (total amount of relations 5542)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2324654'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2324654: added 0 friends (total amount of relations 5542)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2389239'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2389239: added 0 friends (total amount of relations 5542)
# 2404105: added 100 friends (total amount of relations 5642)
# 2406960: added 100 friends (total amount of relations 5742)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2448344'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2448344: added 0 friends (total amount of relations 5742)
# 2652983: added 100 friends (total amount of relations 5842)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2667147'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2667147: added 0 friends (total amount of relations 5842)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2752589'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2752589: added 0 friends (total amount of relations 5842)
# 2813860: added 100 friends (total amount of relations 5942)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2876925'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2876925: added 0 friends (total amount of relations 5942)
# 2954540: added 100 friends (total amount of relations 6042)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '3020850'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 3020850: added 0 friends (total amount of relations 6042)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '3134006'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 3134006: added 0 friends (total amount of relations 6042)
# 3275224: added 100 friends (total amount of relations 6142)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '3359967'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 3359967: added 0 friends (total amount of relations 6142)
# 3419507: added 100 friends (total amount of relations 6242)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '3433573'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 3433573: added 0 friends (total amount of relations 6242)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '3438755'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 3438755: added 0 friends (total amount of relations 6242)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '3543458'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 3543458: added 0 friends (total amount of relations 6242)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '3565076'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 3565076: added 0 friends (total amount of relations 6242)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '3565139'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 3565139: added 0 friends (total amount of relations 6242)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '3579008'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 3579008: added 0 friends (total amount of relations 6242)
# 3590325: added 100 friends (total amount of relations 6342)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '3647331'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 3647331: added 0 friends (total amount of relations 6342)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '3715525'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 3715525: added 0 friends (total amount of relations 6342)
# 3721648: added 51 friends (total amount of relations 6393)
# 3821065: added 100 friends (total amount of relations 6493)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '3925862'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 3925862: added 0 friends (total amount of relations 6493)
# 3978263: added 100 friends (total amount of relations 6593)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '4040997'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 4040997: added 0 friends (total amount of relations 6593)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '4068083'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 4068083: added 0 friends (total amount of relations 6593)
# 4261581: added 100 friends (total amount of relations 6693)
# 4273186: added 100 friends (total amount of relations 6793)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '4277240'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 4277240: added 0 friends (total amount of relations 6793)
# 4589490: added 100 friends (total amount of relations 6893)
# 4670058: added 20 friends (total amount of relations 6913)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '4692458'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 4692458: added 0 friends (total amount of relations 6913)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '4719097'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 4719097: added 0 friends (total amount of relations 6913)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '4737534'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 4737534: added 0 friends (total amount of relations 6913)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '5066221'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 5066221: added 0 friends (total amount of relations 6913)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '5182833'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 5182833: added 0 friends (total amount of relations 6913)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '5345338'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 5345338: added 0 friends (total amount of relations 6913)
# 5380498: added 100 friends (total amount of relations 7013)
# 5397638: added 100 friends (total amount of relations 7113)
# 5575978: added 100 friends (total amount of relations 7213)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '5698552'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 5698552: added 0 friends (total amount of relations 7213)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '423054'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 423054: added 0 friends (total amount of relations 7213)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '658199'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 658199: added 0 friends (total amount of relations 7213)
# 1072800: added 100 friends (total amount of relations 7313)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1324349'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1324349: added 0 friends (total amount of relations 7313)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1930553'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1930553: added 0 friends (total amount of relations 7313)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '1949571'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 1949571: added 0 friends (total amount of relations 7313)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2205200'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2205200: added 0 friends (total amount of relations 7313)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2234643'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2234643: added 0 friends (total amount of relations 7313)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2332948'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2332948: added 0 friends (total amount of relations 7313)
# 2335597: added 100 friends (total amount of relations 7413)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2656796'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2656796: added 0 friends (total amount of relations 7413)
# 4267659: added 100 friends (total amount of relations 7513)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '4477702'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 4477702: added 0 friends (total amount of relations 7513)
# 4568155: added 100 friends (total amount of relations 7613)
# 6581497: added 100 friends (total amount of relations 7713)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '7006607'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 7006607: added 0 friends (total amount of relations 7713)
# 7118886: added 100 friends (total amount of relations 7813)
# 7162949: added 100 friends (total amount of relations 7913)
# 7256507: added 100 friends (total amount of relations 8013)
# 8870691: added 100 friends (total amount of relations 8113)
# 9366376: added 100 friends (total amount of relations 8213)
# 10406325: added 100 friends (total amount of relations 8313)
# 14668279: added 100 friends (total amount of relations 8413)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '18576450'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 18576450: added 0 friends (total amount of relations 8413)
# 20622620: added 100 friends (total amount of relations 8513)
# 21119313: added 100 friends (total amount of relations 8613)
# 23167712: added 42 friends (total amount of relations 8655)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '25571351'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 25571351: added 0 friends (total amount of relations 8655)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '27343422'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 27343422: added 0 friends (total amount of relations 8655)
# 28480028: added 29 friends (total amount of relations 8684)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '33524454'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 33524454: added 0 friends (total amount of relations 8684)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '38826859'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 38826859: added 0 friends (total amount of relations 8684)
# 53601821: added 100 friends (total amount of relations 8784)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '53647074'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 53647074: added 0 friends (total amount of relations 8784)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '55275073'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 55275073: added 0 friends (total amount of relations 8784)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '65551818'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 65551818: added 0 friends (total amount of relations 8784)
# 67035571: added 100 friends (total amount of relations 8884)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '68024683'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 68024683: added 0 friends (total amount of relations 8884)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '69002923'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 69002923: added 0 friends (total amount of relations 8884)
# 75032353: added 21 friends (total amount of relations 8905)
# 87774082: added 100 friends (total amount of relations 9005)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '87893655'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 87893655: added 0 friends (total amount of relations 9005)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '91579243'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 91579243: added 0 friends (total amount of relations 9005)
# 92675949: added 22 friends (total amount of relations 9027)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '109375337'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 109375337: added 0 friends (total amount of relations 9027)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '111437347'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 111437347: added 0 friends (total amount of relations 9027)
# 142046294: added 100 friends (total amount of relations 9127)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '199069258'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 199069258: added 0 friends (total amount of relations 9127)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '209021028'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 209021028: added 0 friends (total amount of relations 9127)
# 217240359: added 12 friends (total amount of relations 9139)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '232668718'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 232668718: added 0 friends (total amount of relations 9139)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '238129149'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 238129149: added 0 friends (total amount of relations 9139)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '238145651'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 238145651: added 0 friends (total amount of relations 9139)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '244017436'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 244017436: added 0 friends (total amount of relations 9139)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '282837551'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 282837551: added 0 friends (total amount of relations 9139)
# 291891038: added 27 friends (total amount of relations 9166)
# 293023081: added 44 friends (total amount of relations 9210)
# 308553246: added 23 friends (total amount of relations 9233)
# 313255086: added 99 friends (total amount of relations 9332)
# 337495770: added 100 friends (total amount of relations 9432)
# 340807242: added 58 friends (total amount of relations 9490)
# 388127520: added 4 friends (total amount of relations 9494)
# 392826953: added 39 friends (total amount of relations 9533)
# 430430641: added 100 friends (total amount of relations 9633)
# 446538750: added 47 friends (total amount of relations 9680)
# 461064904: added 12 friends (total amount of relations 9692)
# 473312298: added 22 friends (total amount of relations 9714)
# 521366503: added 100 friends (total amount of relations 9814)
# 528532838: added 100 friends (total amount of relations 9914)
# 543326850: added 100 friends (total amount of relations 10014)
# 559424831: added 91 friends (total amount of relations 10105)
# 560126499: added 100 friends (total amount of relations 10205)
# 561564375: added 100 friends (total amount of relations 10305)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '594769938'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 594769938: added 0 friends (total amount of relations 10305)
# 595641257: added 12 friends (total amount of relations 10317)
# 596582228: added 100 friends (total amount of relations 10417)
# 674496316: added 89 friends (total amount of relations 10506)
# 679210333: added 100 friends (total amount of relations 10606)
# 710338828: added 100 friends (total amount of relations 10706)
# 734684948: added 48 friends (total amount of relations 10754)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '767535995'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 767535995: added 0 friends (total amount of relations 10754)
# 880593162: added 20 friends (total amount of relations 10774)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '338872'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 338872: added 0 friends (total amount of relations 10774)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '387282'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 387282: added 0 friends (total amount of relations 10774)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '420165'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 420165: added 0 friends (total amount of relations 10774)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '832532'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 832532: added 0 friends (total amount of relations 10774)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2165464'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2165464: added 0 friends (total amount of relations 10774)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2173962'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2173962: added 0 friends (total amount of relations 10774)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '2854918'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 2854918: added 0 friends (total amount of relations 10774)
# 2912240: added 100 friends (total amount of relations 10874)
# 4372763: added 100 friends (total amount of relations 10974)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '4496799'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 4496799: added 0 friends (total amount of relations 10974)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '5564342'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 5564342: added 0 friends (total amount of relations 10974)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '5617621'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 5617621: added 0 friends (total amount of relations 10974)
# 6213405: added 100 friends (total amount of relations 11074)
# 6236285: added 100 friends (total amount of relations 11174)
# 6829208: added 100 friends (total amount of relations 11274)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '10450887'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 10450887: added 0 friends (total amount of relations 11274)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '10539222'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 10539222: added 0 friends (total amount of relations 11274)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '12848192'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 12848192: added 0 friends (total amount of relations 11274)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '13126027'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 13126027: added 0 friends (total amount of relations 11274)
# 13380686: added 100 friends (total amount of relations 11374)
# 13794460: added 100 friends (total amount of relations 11474)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '14496404'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 14496404: added 0 friends (total amount of relations 11474)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '15405808'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 15405808: added 0 friends (total amount of relations 11474)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '15583253'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 15583253: added 0 friends (total amount of relations 11474)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '15600362'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 15600362: added 0 friends (total amount of relations 11474)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '16849702'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 16849702: added 0 friends (total amount of relations 11474)
# 17170668: added 100 friends (total amount of relations 11574)
# 17668205: added 100 friends (total amount of relations 11674)
# 17840145: added 100 friends (total amount of relations 11774)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '18489547'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 18489547: added 0 friends (total amount of relations 11774)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '20098418'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 20098418: added 0 friends (total amount of relations 11774)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '20629671'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 20629671: added 0 friends (total amount of relations 11774)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '22911280'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 22911280: added 0 friends (total amount of relations 11774)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '23232354'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 23232354: added 0 friends (total amount of relations 11774)
# 27982704: added 100 friends (total amount of relations 11874)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '31252177'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 31252177: added 0 friends (total amount of relations 11874)
# VK error: {'error': {'error_code': 30, 'error_msg': 'This profile is private', 'request_params': [{'key': 'user_id', 'value': '32274534'}, {'key': 'v', 'value': '5.199'}, {'key': 'method', 'value': 'friends.get'}, {'key': 'oauth', 'value': '1'}]}}
# 32274534: added 0 friends (total amount of relations 11874)
# 32421121: added 100 friends (total amount of relations 11974)
# 37448224: added 100 friends (total amount of relations 12000)
#
# Collecting finished: 12000 relations
# Data saved

# %% [markdown]
# <b>Импорт данных</b>

# %%
df = pd.read_excel("vk_friends_limited.xlsx")

df = df[(df["name_1"] != "DELETED ") & (df["name_2"] != "DELETED ")]

print(f"Осталось записей: {len(df)}")
df.head()
# Out:
# Осталось записей: 11943
#    id  user_id_1           name_1  user_id_2             name_2
# 0   1  293108529  Artyom Lisitsin    1093805        David Berov
# 1   2  293108529  Artyom Lisitsin    5372286  Viktoria Lobanova
# 2   3  293108529  Artyom Lisitsin   14659428  Irina Dolgonosova
# 3   4  293108529  Artyom Lisitsin   45210966  Natalya Lisitsina
# 4   5  293108529  Artyom Lisitsin   51256587   Alexander Gromov

# %%
df.to_excel("vk_friends_clean.xlsx", index=False)

# %% [markdown]
# Выбор пользователей для исследования

# %%
selected_users = ["Artyom Lisitsin", "Alexander Gromov", "Litvinenko Viktor", "Andrey Klimov", "Anna Vasichkina"]

# %% [markdown]
# <b>Матрица смежности</b>

# %%
users_1 = df[['user_id_1', 'name_1']].drop_duplicates()
users_2 = df[['user_id_2', 'name_2']].drop_duplicates()

users_1.columns = ['user_id', 'name']
users_2.columns = ['user_id', 'name']

all_users_df = pd.concat([users_1, users_2]).drop_duplicates().reset_index(drop=True)
all_users = all_users_df['user_id'].values
user_to_index = {user_id: i for i, user_id in enumerate(all_users)}
index_to_name = {i: all_users_df.loc[i, 'name'] for i in range(len(all_users))}
name_to_index = {v: k for k, v in index_to_name.items()}
n = len(all_users)

A = np.zeros((n, n))
for _, row in df.iterrows():
    i = user_to_index[row['user_id_1']]
    j = user_to_index[row['user_id_2']]
    A[i, j] = 1
    A[j, i] = 1

# %% [markdown]
# Создание графа для подсчета по встроенным функциям

# %%
G = nx.Graph()

for _, row in df.iterrows():
    G.add_edge(row["name_1"], row["name_2"])

all_users = pd.unique(df[['user_id_1', 'user_id_2']].values.ravel())

# %% [markdown]
# <b>Центральность по собственному вектору</b>

# %% [markdown]
# <img src="./img/eigenvector/eigenvector1.png" width="1000">
# <img src="./img/eigenvector/eigenvector2.png" width="1000">
# <img src="./img/eigenvector/eigenvector3.png" width="1000">

# %% [markdown]
# Использование встроенных функций

# %%
centrality = nx.eigenvector_centrality(G, max_iter=1000)

centrality_df = pd.DataFrame(list(centrality.items()), columns=['user_id', 'eigenvector_centrality'])

centrality_df = centrality_df.sort_values(by='eigenvector_centrality', ascending=False)

display(centrality_df[['user_id', 'eigenvector_centrality']].head(5).style.hide(axis="index"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_09475">
#   <thead>
#     <tr>
#       <th id="T_09475_level0_col0" class="col_heading level0 col0" >user_id</th>
#       <th id="T_09475_level0_col1" class="col_heading level0 col1" >eigenvector_centrality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_09475_row0_col0" class="data row0 col0" >Galina Vasichkina</td>
#       <td id="T_09475_row0_col1" class="data row0 col1" >0.276678</td>
#     </tr>
#     <tr>
#       <td id="T_09475_row1_col0" class="data row1 col0" >Nikolay Lisitsyn</td>
#       <td id="T_09475_row1_col1" class="data row1 col1" >0.262673</td>
#     </tr>
#     <tr>
#       <td id="T_09475_row2_col0" class="data row2 col0" >Elena Lisitsyna</td>
#       <td id="T_09475_row2_col1" class="data row2 col1" >0.255448</td>
#     </tr>
#     <tr>
#       <td id="T_09475_row3_col0" class="data row3 col0" >Andrey Lisitsin</td>
#       <td id="T_09475_row3_col1" class="data row3 col1" >0.231010</td>
#     </tr>
#     <tr>
#       <td id="T_09475_row4_col0" class="data row4 col0" >Vasichkin Igor</td>
#       <td id="T_09475_row4_col1" class="data row4 col1" >0.229893</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Использование собственных функций

# %%
def eigenvector_centrality(A, max_iter=1000, tol=1e-6):
    n = A.shape[0]
    x = np.ones(n)
    x = x / np.sqrt(np.sum(x**2))

    for _ in range(max_iter):
        x_new = A @ x
        x_new = x_new / np.sqrt(np.sum(x_new**2))
        if np.sqrt(np.sum((x_new - x)**2)) < tol:
            break
        x = x_new
    return x

centrality = eigenvector_centrality(A)

centrality_df = pd.DataFrame({
    'name': [index_to_name[i] for i in range(n)],
    'eigenvector_centrality': centrality
})

centrality_df = centrality_df.sort_values(by='eigenvector_centrality', ascending=False)

display(centrality_df[['name', 'eigenvector_centrality']].head(5).style.hide(axis="index"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_eb1f7">
#   <thead>
#     <tr>
#       <th id="T_eb1f7_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_eb1f7_level0_col1" class="col_heading level0 col1" >eigenvector_centrality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_eb1f7_row0_col0" class="data row0 col0" >Galina Vasichkina</td>
#       <td id="T_eb1f7_row0_col1" class="data row0 col1" >0.281044</td>
#     </tr>
#     <tr>
#       <td id="T_eb1f7_row1_col0" class="data row1 col0" >Nikolay Lisitsyn</td>
#       <td id="T_eb1f7_row1_col1" class="data row1 col1" >0.266234</td>
#     </tr>
#     <tr>
#       <td id="T_eb1f7_row2_col0" class="data row2 col0" >Elena Lisitsyna</td>
#       <td id="T_eb1f7_row2_col1" class="data row2 col1" >0.249564</td>
#     </tr>
#     <tr>
#       <td id="T_eb1f7_row3_col0" class="data row3 col0" >Vasichkin Igor</td>
#       <td id="T_eb1f7_row3_col1" class="data row3 col1" >0.234482</td>
#     </tr>
#     <tr>
#       <td id="T_eb1f7_row4_col0" class="data row4 col0" >Natalya Lisitsyna</td>
#       <td id="T_eb1f7_row4_col1" class="data row4 col1" >0.232155</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <b>Центральность по близости</b>

# %% [markdown]
# <img src="./img/closeness/closeness1.png" width="1000">
# <img src="./img/closeness/closeness2.png" width="1000">
# <img src="./img/closeness/closeness3.png" width="1000">
# <img src="./img/closeness/closeness4.png" width="1000">

# %% [markdown]
# Использование встроенных функций

# %%
closeness_centrality = nx.closeness_centrality(G)

closeness_df = pd.DataFrame(list(closeness_centrality.items()), columns=['name', 'closeness_centrality'])

closeness_selected_df = closeness_df[closeness_df['name'].isin(selected_users)]

closeness_selected_df = closeness_selected_df.sort_values(by='closeness_centrality', ascending=False)

display(closeness_selected_df.style.hide(axis="index"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_bdf9f">
#   <thead>
#     <tr>
#       <th id="T_bdf9f_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_bdf9f_level0_col1" class="col_heading level0 col1" >closeness_centrality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bdf9f_row0_col0" class="data row0 col0" >Artyom Lisitsin</td>
#       <td id="T_bdf9f_row0_col1" class="data row0 col1" >0.367267</td>
#     </tr>
#     <tr>
#       <td id="T_bdf9f_row1_col0" class="data row1 col0" >Alexander Gromov</td>
#       <td id="T_bdf9f_row1_col1" class="data row1 col1" >0.293219</td>
#     </tr>
#     <tr>
#       <td id="T_bdf9f_row2_col0" class="data row2 col0" >Litvinenko Viktor</td>
#       <td id="T_bdf9f_row2_col1" class="data row2 col1" >0.273757</td>
#     </tr>
#     <tr>
#       <td id="T_bdf9f_row3_col0" class="data row3 col0" >Andrey Klimov</td>
#       <td id="T_bdf9f_row3_col1" class="data row3 col1" >0.272328</td>
#     </tr>
#     <tr>
#       <td id="T_bdf9f_row4_col0" class="data row4 col0" >Anna Vasichkina</td>
#       <td id="T_bdf9f_row4_col1" class="data row4 col1" >0.267849</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Использование собственных функций

# %%
def bfs_shortest_paths(A, start_idx):
    n = A.shape[0]
    distances = np.full(n, np.inf)
    distances[start_idx] = 0
    queue = deque([start_idx])
    
    while queue:
        current = queue.popleft()
        neighbors = np.where(A[current] > 0)[0]
        for neighbor in neighbors:
            if distances[neighbor] == np.inf:
                distances[neighbor] = distances[current] + 1
                queue.append(neighbor)
    return distances

def closeness_centrality(A):
    n = A.shape[0]
    centrality = np.zeros(n)
    
    for i in range(n):
        distances = bfs_shortest_paths(A, i)
        reachable = distances[distances < np.inf]
        if len(reachable) > 1:
            centrality[i] = ((len(reachable) - 1) / np.sum(reachable[1:])) * ((len(reachable) - 1) / (n - 1))
        else:
            centrality[i] = 0
    return centrality

closeness = closeness_centrality(A)

selected_closeness = {name: closeness[name_to_index[name]] for name in selected_users}

selected_df = pd.DataFrame({
    'name': list(selected_closeness.keys()),
    'closeness_centrality': list(selected_closeness.values())
}).sort_values(by='closeness_centrality', ascending=False)

display(selected_df.style.hide(axis="index"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_19517">
#   <thead>
#     <tr>
#       <th id="T_19517_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_19517_level0_col1" class="col_heading level0 col1" >closeness_centrality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_19517_row0_col0" class="data row0 col0" >Artyom Lisitsin</td>
#       <td id="T_19517_row0_col1" class="data row0 col1" >0.366549</td>
#     </tr>
#     <tr>
#       <td id="T_19517_row1_col0" class="data row1 col0" >Litvinenko Viktor</td>
#       <td id="T_19517_row1_col1" class="data row1 col1" >0.271951</td>
#     </tr>
#     <tr>
#       <td id="T_19517_row2_col0" class="data row2 col0" >Andrey Klimov</td>
#       <td id="T_19517_row2_col1" class="data row2 col1" >0.254655</td>
#     </tr>
#     <tr>
#       <td id="T_19517_row3_col0" class="data row3 col0" >Anna Vasichkina</td>
#       <td id="T_19517_row3_col1" class="data row3 col1" >0.246981</td>
#     </tr>
#     <tr>
#       <td id="T_19517_row4_col0" class="data row4 col0" >Alexander Gromov</td>
#       <td id="T_19517_row4_col1" class="data row4 col1" >0.196429</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <b>Центральность по посредничеству</b>

# %% [markdown]
# <img src="./img/betweenness/betweenness1.png" width="1000">
# <img src="./img/betweenness/betweenness2.png" width="1000">
# <img src="./img/betweenness/betweenness3.png" width="1000">
# <img src="./img/betweenness/betweenness4.png" width="1000">
# <img src="./img/betweenness/betweenness5.png" width="1000">

# %% [markdown]
# Использование встроенных функций

# %%
betweenness_centrality = nx.betweenness_centrality(G, normalized=True)

betweenness_df = pd.DataFrame(list(betweenness_centrality.items()), columns=['name', 'betweenness_centrality'])

betweenness_selected_df = betweenness_df[closeness_df['name'].isin(selected_users)]

betweenness_selected_df = betweenness_selected_df.sort_values(by='betweenness_centrality', ascending=False)

display(betweenness_selected_df.style.hide(axis="index"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_2e49c">
#   <thead>
#     <tr>
#       <th id="T_2e49c_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_2e49c_level0_col1" class="col_heading level0 col1" >betweenness_centrality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2e49c_row0_col0" class="data row0 col0" >Artyom Lisitsin</td>
#       <td id="T_2e49c_row0_col1" class="data row0 col1" >0.388712</td>
#     </tr>
#     <tr>
#       <td id="T_2e49c_row1_col0" class="data row1 col0" >Alexander Gromov</td>
#       <td id="T_2e49c_row1_col1" class="data row1 col1" >0.113685</td>
#     </tr>
#     <tr>
#       <td id="T_2e49c_row2_col0" class="data row2 col0" >Andrey Klimov</td>
#       <td id="T_2e49c_row2_col1" class="data row2 col1" >0.019807</td>
#     </tr>
#     <tr>
#       <td id="T_2e49c_row3_col0" class="data row3 col0" >Anna Vasichkina</td>
#       <td id="T_2e49c_row3_col1" class="data row3 col1" >0.019412</td>
#     </tr>
#     <tr>
#       <td id="T_2e49c_row4_col0" class="data row4 col0" >Litvinenko Viktor</td>
#       <td id="T_2e49c_row4_col1" class="data row4 col1" >0.015799</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Использование собственных функций

# %%
def betweenness_centrality_selected(A, selected_indices, normalized=True):
    n = A.shape[0]
    CB = np.zeros(n)

    for s in range(n):
        S = []
        P = [[] for _ in range(n)]
        sigma = np.zeros(n)
        d = np.full(n, -1)
        sigma[s] = 1
        d[s] = 0
        Q = deque([s])

        while Q:
            v = Q.popleft()
            S.append(v)
            neighbors = np.where(A[v] > 0)[0]
            for w in neighbors:
                if d[w] < 0:
                    Q.append(w)
                    d[w] = d[v] + 1
                if d[w] == d[v] + 1:
                    sigma[w] += sigma[v]
                    P[w].append(v)

        delta = np.zeros(n)
        while S:
            w = S.pop()
            for v in P[w]:
                delta[v] += (sigma[v] / sigma[w]) * (1 + delta[w])
            if w != s:
                CB[w] += delta[w]

    CB /= 2

    if normalized and n > 1:
        factor = 2 / (n * (n - 1))
        CB *= factor

    return {idx: CB[idx] for idx in selected_indices}

selected_indices = [name_to_index[name] for name in selected_users]

betweenness_selected = betweenness_centrality_selected(A, selected_indices)

betweenness_selected_df = pd.DataFrame({
    'name': selected_users,
    'betweenness_centrality': [betweenness_selected[name_to_index[name]] for name in selected_users]
}).sort_values(by='betweenness_centrality', ascending=False)

display(betweenness_selected_df.style.hide(axis="index"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_1ddab">
#   <thead>
#     <tr>
#       <th id="T_1ddab_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_1ddab_level0_col1" class="col_heading level0 col1" >betweenness_centrality</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_1ddab_row0_col0" class="data row0 col0" >Artyom Lisitsin</td>
#       <td id="T_1ddab_row0_col1" class="data row0 col1" >0.659176</td>
#     </tr>
#     <tr>
#       <td id="T_1ddab_row1_col0" class="data row1 col0" >Andrey Klimov</td>
#       <td id="T_1ddab_row1_col1" class="data row1 col1" >0.018997</td>
#     </tr>
#     <tr>
#       <td id="T_1ddab_row2_col0" class="data row2 col0" >Anna Vasichkina</td>
#       <td id="T_1ddab_row2_col1" class="data row2 col1" >0.016436</td>
#     </tr>
#     <tr>
#       <td id="T_1ddab_row3_col0" class="data row3 col0" >Litvinenko Viktor</td>
#       <td id="T_1ddab_row3_col1" class="data row3 col1" >0.015681</td>
#     </tr>
#     <tr>
#       <td id="T_1ddab_row4_col0" class="data row4 col0" >David Berov</td>
#       <td id="T_1ddab_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <b>Отображение графа</b>

# %%
G = nx.Graph()
for _, row in df.iterrows():
    G.add_edge(row["name_1"], row["name_2"])

# %% [markdown]
# Граф для пользователей по центральности собственного вектора

# %%
eigen_dict = {index_to_name[i]: centrality[i] for i in range(n)}

top_n = 50
top_indices = np.argsort(-centrality)[:top_n]
top_nodes = [index_to_name[i] for i in top_indices]
H = G.subgraph(top_nodes)

pos = nx.spring_layout(H, seed=42, k=0.45, iterations=100)

node_sizes = [6000 * eigen_dict[n] for n in H.nodes()]
node_colors = [eigen_dict[n] for n in H.nodes()]

plt.figure(figsize=(15, 15))

nx.draw_networkx_edges(H, pos, alpha=0.25, edge_color='gray', width=0.8)

nx.draw_networkx_nodes(
    H, pos,
    node_size=node_sizes,
    node_color=node_colors,
    cmap=plt.cm.plasma,
    alpha=0.95,
    edgecolors='black',
    linewidths=0.7
)

top_labels = set([index_to_name[i] for i in top_indices[:10]])
labels = {n: n for n in H.nodes() if n in top_labels}
nx.draw_networkx_labels(H, pos, labels, font_size=9, font_weight='bold')

nodes = nx.draw_networkx_nodes(
    H, pos,
    node_size=node_sizes,
    node_color=node_colors,
    cmap=plt.cm.plasma,
    alpha=0.95,
    edgecolors='black',
    linewidths=0.7
)

plt.colorbar(nodes, label='Eigenvector Centrality')

plt.title("Топ-50 пользователей по центральности собственного вектора", fontsize=15, pad=20)
plt.axis('off')
plt.tight_layout()
plt.savefig("./results/graph_top50_eigen.png", format='png', dpi=300)
plt.show()

# %% [markdown]
# Граф для пользователей по центральности по близости

# %%
closeness_dict = {index_to_name[i]: closeness[i] for i in range(n)}

plt.figure(figsize=(15, 15))

nx.draw_networkx_edges(H, pos, alpha=0.3, edge_color='gray', width=0.8)

nodes = nx.draw_networkx_nodes(
    H, pos,
    node_size=600,
    node_color=[closeness_dict[n] for n in H.nodes()],
    cmap=plt.cm.plasma,
    alpha=0.9,
    edgecolors='black',
    linewidths=0.5
)

top_labels = sorted(closeness_dict, key=closeness_dict.get, reverse=True)[:10]
labels = {n: n for n in H.nodes() if n in top_labels}
nx.draw_networkx_labels(H, pos, labels, font_size=9, font_weight='bold')

plt.colorbar(nodes, label='Центральность по близости')

plt.title("Визуализация центральности по близости", fontsize=15, pad=20)
plt.axis('off')
plt.tight_layout()
plt.savefig("./results/graph_closeness.png", format='png', dpi=300)
plt.show()
